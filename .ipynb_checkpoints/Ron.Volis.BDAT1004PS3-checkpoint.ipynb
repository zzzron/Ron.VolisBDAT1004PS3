# %% [markdown]
# ### BDAT1004 Problem Set 3 Python Questions - Ron Volis

# %% [markdown]
# ### Question 3
# Housing
#
# Step 1. Import the necessary libraries
#
# Step 2. Create 3 differents Series, each of length 100, as follows:
#
#     • The first a random number from 1 to 4
#
#     • The second a random number from 1 to 3
#
#     • The third a random number from 10,000 to 30,000
#
# Step 3. Create a DataFrame by joinning the Series by column
#
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
#
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'
#
# Step 6. Ops it seems it is going only until index 99. Is it true?
#
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
import pandas as pd
import numpy as np

s1 = pd.Series(index=range(100))
s2 = pd.Series(index=range(100))
s3 = pd.Series(index=range(100))

for i in range(0, 100):
    s1[i] = np.random.randint(1, 4)
    s2[i] = np.random.randint(1, 3)
    s3[i] = np.random.randint(10000, 30000)
    
df = pd.concat([s1, s2, s3], axis=1)

df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']

s4 = s1.append(s2).append(s3)
df2 = pd.DataFrame(s4)
df2.columns = ['bigcolumn']

#only indexes to 99

df2 = df2.reset_index(drop=True)
df2.reindex(index = range(300))

df2
# Out:
# <ipython-input-55-1905e2f12ddc>:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s1 = pd.Series(index=range(100))
# <ipython-input-55-1905e2f12ddc>:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s2 = pd.Series(index=range(100))
# <ipython-input-55-1905e2f12ddc>:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s3 = pd.Series(index=range(100))
#      bigcolumn
# 0          2.0
# 1          1.0
# 2          2.0
# 3          2.0
# 4          2.0
# ..         ...
# 295    26162.0
# 296    26355.0
# 297    26547.0
# 298    10278.0
# 299    12633.0
#
# [300 rows x 1 columns]

# %% [markdown]
# ## Question 4 Python
# Wind Statistics
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL
# MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
#
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.
# A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days
# A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.
# A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location.
#  BDAT 1004 – D
#
# Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on
# January 2 1961) for the first 52 weeks.

# %%
data = pd.read_fwf('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data', sep=' ', header=1)

data['Date'] = data[data.columns[:3]].apply(lambda x: '-'.join(x.astype(str)), axis=1)
data = data.drop(columns=data.columns[:3])


data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL      Date
# 0     18.50  15.04    61-1-1
# ...

# %% [markdown]
# ## Question 5 Python
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address.
#
# Step 3. Assign it to a variable called chipo.
#
# Step 4. See the first 10 entries
#
# Step 5. What is the number of observations in the dataset?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. Print the name of all the columns.
#
# Step 8. How is the dataset indexed?
#
# Step 9. Which was the most-ordered item?
#
# Step 10. For the most-ordered item, how many items were ordered?
#
# Step 11. What was the most ordered item in the choice_description column?
#
# Step 12. How many items were orderd in total?
#
# Step 13.
#
#     • Turn the item price into a float
#     • Check the item price type
#     • Create a lambda function and change the type of item price
#     • Check the item price type
#
# Step 14. How much was the revenue for the period in the dataset?
#
# Step 15. How many orders were made in the period?
#
# Step 16. What is the average revenue amount per order?
#
# Step 17. How many different items are sold?

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

print(F'What is the number of observations in the dataset? {len(chipo.head(10))}')
print(F'What is the number of columns in the dataset? {len(chipo.columns)}')
print(chipo.columns)
print(F'How is the dataset indexed? {chipo.index}')
print(F'Which was the most-ordered item? {chipo["item_name"].value_counts().idxmax()}')
print(F'Which was the most-ordered item? {chipo["item_name"].value_counts().max()}')
print(F'What was the most ordered item in the choice_description column? {chipo["choice_description"].value_counts().idxmax()}')
print(F'How many items were orderd in total? {len(chipo)}')

total_revenue = chipo["item_price"].sum()
#print(F' How much was the revenue for the period in the dataset? {total_revenue}')
print(F'How many orders were made in the period? {chipo["order_id"].max()}')
print(F'How many different items are sold? {chipo["item_name"].nunique()}')

chipo.head(10)
# Out:
# What is the number of observations in the dataset? 10
# What is the number of columns in the dataset? 5
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')
# How is the dataset indexed? RangeIndex(start=0, stop=4622, step=1)
# Which was the most-ordered item? Chicken Bowl
# Which was the most-ordered item? 726
# What was the most ordered item in the choice_description column? [Diet Coke]
# How many items were orderd in total? 4622
# How many orders were made in the period? 1834
# How many different items are sold? 50
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# ...

# %% [markdown]
# ## Question 6 Python
#
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import seaborn as sns

mardiv = pd.read_csv('us-marriages-divorces-1867-2014.csv')

ax = sns.lineplot(x = 'Year', y='Marriages_per_1000', data=mardiv, color='Black', label='Marriages per 1000 ')
ax = sns.lineplot(x = 'Year', y='Divorces_per_1000', data=mardiv, color='Red', label='Diviroces per 1000')
ax.set(ylabel='Rate per 1000 people', title='Marriages vs Divorces Per Capita')
ax.legend()

# %% [markdown]
# ## Question 7 Python
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
ax = sns.barplot(x = 'Year', order=[1900, 1950, 2000], y='Marriages_per_1000', data=mardiv, color='Black', label='Marriages per 1000 ')
ax = sns.barplot(x = 'Year', order=[1900, 1950, 2000], y='Divorces_per_1000', data=mardiv, color='Red', label='Diviroces per 1000')
ax.set(ylabel='Rate per 1000 people', title='Marriages vs Divorces Per Capita')
ax.legend()

# %% [markdown]
# ## Question 8 Python
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
deadliest = pd.read_csv('actor_kill_counts.csv')

deadliest = deadliest.sort_values('Count', ascending=False)
ax = sns.barplot(x='Count', y='Actor', data=deadliest)
ax.set(title='Kill Counts')

for index, row in deadliest.iterrows():
    ax.text(row.Count, row.name, round(row.Count, 2), color='black', ha='center')

# %% [markdown]
# ## Question 9 Python
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
reigns = pd.read_csv('roman-emperor-reigns.csv')

pie, ax = plt.subplots(figsize=[10,10])
labels = reigns.keys()

assassinated = 0
for cause in reigns['Cause_of_Death']:
    if cause == 'Assassinated':
        assassinated += 1

data = [assassinated, len(reigns['Cause_of_Death'])-assassinated]
ax = plt.pie(data, autopct='%.1f%%', labels=['Assassinated', 'Not Assassinated'])
plt.legend()

# %% [markdown]
# ## Question 10 Python
#
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
arcade = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

ax = sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', data=arcade)
ax.set(title='Arcade Revenue vs PhDs Awarded')
# Out:
# [Text(0.5, 1.0, 'Arcade Revenue vs PhDs Awarded')]
